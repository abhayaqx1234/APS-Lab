# %% [markdown]
# <a href="https://colab.research.google.com/github/abhayaqx1234/APS-Lab/blob/main/Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %%
def prim_algorithm(graph):
    min_tree = {}
    visited = set()
    min_tree[list(graph.keys())[0]] = []
    min_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        next_vertex = None
        for vertex in min_tree:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited:
                    if weight < min_edge:
                        min_edge = weight
                        next_vertex = adj_vertex

        min_tree[next_vertex] = []
        visited.add(next_vertex)
        min_weight += min_edge

    return min_tree, min_weight

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  {'A': [], 'B': [], 'C': [], 'D': []}
# Minimum Weight:  50

# %% [markdown]
# Take Differnt example of input graph as discussed in lecture slide and use above code to verify the output

# %%
graph_2 = {
    'A': {'B': 7, 'D': 5},
    'B': {'A': 7, 'C': 8, 'D': 9, 'E': 7},
    'C': {'B': 8, 'E': 5},
    'D': {'A': 5, 'B': 9, 'E': 15, 'F': 6},
    'E': {'B': 7, 'C': 5, 'D': 15, 'F': 8, 'G': 9},
    'F': {'D': 6, 'E': 8, 'G': 11},
    'G': {'E': 9, 'F': 11}
}

# %%
mst_2, min_weight_2 = prim_algorithm(graph_2)
print("Minimum Spanning Tree (graph_2): ", mst_2)
print("Minimum Weight (graph_2): ", min_weight_2)
# Out:
# Minimum Spanning Tree (graph_2):  {'A': [], 'D': [], 'F': [], 'B': [], 'E': [], 'C': [], 'G': []}
# Minimum Weight (graph_2):  44

# %% [markdown]
# Use same apporach for Kruskal's algorithm

# %%
def kruskal_algorithm(graph):
    edges = []
    for u in graph:
        for v, weight in graph[u].items():
            edges.append((weight, u, v))
    edges.sort()

    parent = {vertex: vertex for vertex in graph}
    rank = {vertex: 0 for vertex in graph}

    def find(i):
        if parent[i] == i:
            return i
        parent[i] = find(parent[i])
        return parent[i]

    def union(i, j):
        root_i = find(i)
        root_j = find(j)
        if root_i != root_j:
            if rank[root_i] < rank[root_j]:
                parent[root_i] = root_j
            elif rank[root_i] > rank[root_j]:
                parent[root_j] = root_i
            else:
                parent[root_j] = root_i
                rank[root_i] += 1
            return True
        return False

    min_tree_edges = []
    min_weight = 0
    num_vertices = len(graph)

    for weight, u, v in edges:
        if len(min_tree_edges) == num_vertices - 1:
            break
        if union(u, v):
            min_tree_edges.append((u, v, weight))
            min_weight += weight

    mst_dict = {vertex: [] for vertex in graph}
    for u, v, weight in min_tree_edges:
        mst_dict[u].append((v, weight))
        mst_dict[v].append((u, weight))

    return mst_dict, min_weight

mst_kruskal, min_weight_kruskal = kruskal_algorithm(graph_2)
print("Minimum Spanning Tree (Kruskal, graph_2): ", mst_kruskal)
print("Minimum Weight (Kruskal, graph_2): ", min_weight_kruskal)
# Out:
# Minimum Spanning Tree (Kruskal, graph_2):  {'A': [('D', 5), ('B', 7)], 'B': [('A', 7), ('E', 7)], 'C': [('E', 5)], 'D': [('A', 5), ('F', 6)], 'E': [('C', 5), ('B', 7), ('G', 9)], 'F': [('D', 6)], 'G': [('E', 9)]}
# Minimum Weight (Kruskal, graph_2):  39
