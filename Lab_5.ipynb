# %% [markdown]
# <a href="https://colab.research.google.com/github/abhayaqx1234/APS-Lab/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
# Step 1: Read number of elements
n = int(input("Enter the number of elements: "))

# Step 2: Insert elements into list
numbers = []
for i in range(n):
    num = int(input("Enter element: "))
    numbers.append(num)

# Step 3, 4: Selection Sort
for i in range(n):
    min = numbers[i]          # Initialize minimum element
    min_index = i

    for j in range(i + 1, n):
        if numbers[j] < min:
            min = numbers[j]
            min_index = j

    # Swap the elements
    numbers[i], numbers[min_index] = numbers[min_index], numbers[i]

# Step 5: Print sorted list
print("Sorted list is:", numbers)
# Out:
# Enter the number of elements: 5
# Enter element: 4
# Enter element: 2
# Enter element: 7
# Enter element: 8
# Enter element: 9
# Sorted list is: [2, 4, 7, 8, 9]

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
import random
import time
import matplotlib.pyplot as plt

# Merge Function
def merge(arr, left, mid, right):
    n1 = mid - left + 1
    n2 = right - mid

    L = arr[left:mid+1]
    R = arr[mid+1:right+1]

    i = j = 0
    k = left

    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1

    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1

    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1


# Merge Sort Function (Divide and Conquer)
def merge_sort(arr, left, right):
    if left < right:
        mid = (left + right) // 2

        merge_sort(arr, left, mid)
        merge_sort(arr, mid + 1, right)

        merge(arr, left, mid, right)


# Measure Time for Different n
sizes = [100, 500]

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
import random
import time
import matplotlib.pyplot as plt

# Partition Function
def partition(arr, low, high):
    pivot = arr[high]   # Select last element as pivot
    i = low - 1

    for j in range(low, high):
        if arr[j] <= pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]

    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1


# Quick Sort Function
def quick_sort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)

        quick_sort(arr, low, pi - 1)
        quick_sort(arr, pi + 1, high)


# Measure Time for Different n
sizes = [100, 500, 1000, 2000, 5000]
times = []

for n in sizes:
    arr = [random.randint(1, 10000) for _ in range(n)]

    start = time.time()
    quick_sort(arr, 0, len(arr) - 1)
    end = time.time()

    times.append(end - start)


# Plot Graph
plt.plot(sizes, times, marker='o')
plt.title("Quick Sort: Time Taken vs n")
plt.xlabel("Number of Elements (n)")
plt.ylabel("Time Taken (seconds)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]

# %%
import time
import matplotlib.pyplot as plt

# Quick sort implementation
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]  # choose middle element as pivot
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# Example list
arr = [5,4,3,2,1,245,67,78,3,245,96,45,56,13,76,13,5,13,3,436,673,465,334,4364,334,3743,46]

# Timing on the small example
st = time.time()
sorted_list = quick_sort(arr.copy())
et = time.time()
print("Time for small list:", et - st)

# Running time for different sizes
time_arr = []
sizes = [100, 1000, 5000, 10000, 20000,50000,100000000]

for s in sizes:
    test_arr = list(range(s, 0, -1))  # worst-case descending order
    st = time.time()
    quick_sort(test_arr)
    et = time.time()
    time_arr.append(et - st)
    print(f"Size {s}: {et - st:.6f} seconds")

# Plotting
plt.plot(sizes, time_arr, marker='o', label="Quick Sort")
plt.xlabel("Input size (n)")
plt.ylabel("Running time (seconds)")
plt.title("Quick Sort Running Time")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Time for small list: 0.00044083595275878906
# Size 100: 0.000143 seconds
# Size 1000: 0.003047 seconds
# Size 5000: 0.011904 seconds
# Size 10000: 0.020951 seconds
# Size 20000: 0.044969 seconds
# Size 50000: 0.124054 seconds

# %%
# Plotting results
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 5))
plt.plot(a_time, linewidth = 1, marker="o", label="Quicksort")
plt.plot(b_time, linewidth = 1, marker="o", label="Mergesort")
plt.plot(c_time, linewidth = 1, marker="o", label="Selection sort")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize = 14)
plt.ylabel('Time (ms)')
plt.xlabel('n')
plt.legend(loc = "best")
plt.grid(True)
plt.show()

# %% [markdown]
# # Task
# Compare the performance of Quick Sort, Merge Sort, and Selection Sort by measuring their execution times for varying input sizes (n) and visualize the results using a line plot.

# %% [markdown]
# ## Prepare Sorting Algorithms and Experiment Data
#
# ### Subtask:
# Define the Quick Sort, Merge Sort, and Selection Sort functions, set up experiment variables (n_list, n_max), generate random test data, and run the comparison for each algorithm across different input sizes. This step will collect the execution times for each sorting algorithm.

# %% [markdown]
# **Reasoning**:
# The subtask requires defining the `selection_sort` function and then executing a comparison experiment for all three sorting algorithms. I will first define the `selection_sort` function based on the existing logic in the notebook. Then, I will create a comprehensive code cell that includes the necessary imports, redefines all three sorting functions (including their helper functions) to ensure they are available, initializes the time tracking lists, and runs the experiment loop to measure the execution times for Quick Sort, Merge Sort, and Selection Sort for various input sizes.

# %%
import random
import time
import matplotlib.pyplot as plt

# Selection Sort Function
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]

# Merge Sort Functions
def merge(arr, left, mid, right):
    n1 = mid - left + 1
    n2 = right - mid

    L = arr[left : mid + 1]
    R = arr[mid + 1 : right + 1]

    i = j = 0
    k = left

    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1

    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1

    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1

def merge_sort(arr, left, right):
    if left < right:
        mid = (left + right) // 2

        merge_sort(arr, left, mid)
        merge_sort(arr, mid + 1, right)

        merge(arr, left, mid, right)

# Quick Sort Functions
def partition(arr, low, high):
    pivot = arr[high]  # Select last element as pivot
    i = low - 1

    for j in range(low, high):
        if arr[j] <= pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]

    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1

def quick_sort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)

        quick_sort(arr, low, pi - 1)
        quick_sort(arr, pi + 1, high)

# Experiment variables (already defined, but good to ensure context)
n_list = [1000, 2000, 5000, 10000, 20000, 50000]
# Reducing n_max for quicker execution if needed, or stick to previous value.
# n_max = n_list[len(n_list) - 1]

# Initialize lists to store execution times
a_time = [] # For Quick Sort
b_time = [] # For Merge Sort
c_time = [] # For Selection Sort

print("Running sorting algorithm comparison...")
for n in n_list:
    print(f"Testing with n = {n} elements...")
    # Generate a random list for the current n
    original_list = [random.randint(1, 10000) for _ in range(n)]

    # Create three copies for each algorithm
    a = list(original_list) # For Quick Sort
    b = list(original_list) # For Merge Sort
    c = list(original_list) # For Selection Sort

    # Measure time for Quick Sort
    start_a = time.time()
    quick_sort(a, 0, len(a) - 1)
    end_a = time.time()
    a_time.append((end_a - start_a) * 1000) # Convert to milliseconds

    # Measure time for Merge Sort
    start_b = time.time()
    merge_sort(b, 0, len(b) - 1)
    end_b = time.time()
    b_time.append((end_b - start_b) * 1000) # Convert to milliseconds

    # Measure time for Selection Sort
    start_c = time.time()
    selection_sort(c)
    end_c = time.time()
    c_time.append((end_c - start_c) * 1000) # Convert to milliseconds

print("Comparison complete.")
print(f"Quick Sort Times (ms): {a_time}")
print(f"Merge Sort Times (ms): {b_time}")
print(f"Selection Sort Times (ms): {c_time}")
# Out:
# Running sorting algorithm comparison...
# Testing with n = 1000 elements...
# Testing with n = 2000 elements...
# Testing with n = 5000 elements...
# Testing with n = 10000 elements...
# Testing with n = 20000 elements...
# Testing with n = 50000 elements...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1239181705.py in <cell line: 0>()
#     107     # Measure time for Selection Sort
#     108     start_c = time.time()
# --> 109     selection_sort(c)
#     110     end_c = time.time()
#     111     c_time.append((end_c - start_c) * 1000) # Convert to milliseconds
#
# /tmp/ipython-input-1239181705.py in selection_sort(arr)
#       9         min_index = i
#      10         for j in range(i + 1, n):
# ---> 11             if arr[j] < arr[min_index]:
#      12                 min_index = j
#      13         arr[i], arr[min_index] = arr[min_index], arr[i]
#
# ...

# %% [markdown]
# # Task
# Proceed to plotting the collected `a_time`, `b_time`, `c_time`, and `n_list` data to visualize the comparison of the sorting algorithms.

# %% [markdown]
# ## Consolidate and Execute Experiment Code
#
# ### Subtask:
# Define the Quick Sort, Merge Sort, and Selection Sort functions, set up experiment variables (n_list, n_max), generate random test data, and run the comparison for each algorithm across different input sizes. This step will collect the execution times for each sorting algorithm.

# %% [markdown]
# **Reasoning**:
# The previous execution of the comparison script was interrupted due to the poor performance of Selection Sort on larger input sizes. To complete the subtask successfully, I will rerun the code with a reduced `n_list` to avoid the `KeyboardInterrupt` and ensure all algorithms finish their execution for the specified input sizes.

# %%
import random
import time
import matplotlib.pyplot as plt

# Selection Sort Function
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]

# Merge Sort Functions
def merge(arr, left, mid, right):
    n1 = mid - left + 1
    n2 = right - mid

    L = arr[left : mid + 1]
    R = arr[mid + 1 : right + 1]

    i = j = 0
    k = left

    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1

    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1

    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1

def merge_sort(arr, left, right):
    if left < right:
        mid = (left + right) // 2

        merge_sort(arr, left, mid)
        merge_sort(arr, mid + 1, right)

        merge(arr, left, mid, right)

# Quick Sort Functions
def partition(arr, low, high):
    pivot = arr[high]  # Select last element as pivot
    i = low - 1

    for j in range(low, high):
        if arr[j] <= pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]

    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1

def quick_sort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)

        quick_sort(arr, low, pi - 1)
        quick_sort(arr, pi + 1, high)

# Experiment variables (updated n_list to avoid KeyboardInterrupt for Selection Sort)
n_list = [1000, 2000, 5000, 10000, 20000]
# n_max = n_list[len(n_list) - 1] # Not needed for this step

# Initialize lists to store execution times
a_time = [] # For Quick Sort
b_time = [] # For Merge Sort
c_time = [] # For Selection Sort

print("Running sorting algorithm comparison...")
for n in n_list:
    print(f"Testing with n = {n} elements...")
    # Generate a random list for the current n
    original_list = [random.randint(1, 10000) for _ in range(n)]

    # Create three copies for each algorithm
    a = list(original_list) # For Quick Sort
    b = list(original_list) # For Merge Sort
    c = list(original_list) # For Selection Sort

    # Measure time for Quick Sort
    start_a = time.time()
    quick_sort(a, 0, len(a) - 1)
    end_a = time.time()
    a_time.append((end_a - start_a) * 1000) # Convert to milliseconds

    # Measure time for Merge Sort
    start_b = time.time()
    merge_sort(b, 0, len(b) - 1)
    end_b = time.time()
    b_time.append((end_b - start_b) * 1000) # Convert to milliseconds

    # Measure time for Selection Sort
    start_c = time.time()
    selection_sort(c)
    end_c = time.time()
    c_time.append((end_c - start_c) * 1000) # Convert to milliseconds

print("Comparison complete.")
print(f"Quick Sort Times (ms): {a_time}")
print(f"Merge Sort Times (ms): {b_time}")
print(f"Selection Sort Times (ms): {c_time}")
# Out:
# Running sorting algorithm comparison...
# Testing with n = 1000 elements...
# Testing with n = 2000 elements...
# Testing with n = 5000 elements...
# Testing with n = 10000 elements...
# Testing with n = 20000 elements...
# Comparison complete.
# Quick Sort Times (ms): [1.6906261444091797, 3.8111209869384766, 26.82948112487793, 14.300107955932617, 32.14383125305176]
# Merge Sort Times (ms): [2.741098403930664, 5.7220458984375, 29.494524002075195, 20.649433135986328, 53.0703067779541]
# Selection Sort Times (ms): [41.480302810668945, 196.58493995666504, 733.3338260650635, 2490.062475204468, 11075.735807418823]

# %% [markdown]
# **Reasoning**:
# The execution times for Quick Sort, Merge Sort, and Selection Sort have been collected for various input sizes. The next step is to visualize these results using a line plot, as indicated by the notebook's task description.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12, 7))
plt.plot(n_list, a_time, linewidth = 2, marker="o", label="Quick Sort")
plt.plot(n_list, b_time, linewidth = 2, marker="o", label="Merge Sort")
plt.plot(n_list, c_time, linewidth = 2, marker="o", label="Selection Sort")

plt.title("Comparison of Sorting Algorithms: Time Taken vs. Number of Elements (n)", fontsize = 16)
plt.ylabel('Time (ms)', fontsize = 12)
plt.xlabel('Number of Elements (n)', fontsize = 12)
plt.xticks(n_list) # Ensure all n values are shown on x-axis
plt.legend(loc = "best")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Proceed to Plotting
#
# ### Subtask:
# Analyze the plot comparing the execution times of Quick Sort, Merge Sort, and Selection Sort for different input sizes (n).

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   The experiment successfully measured the execution times for Quick Sort, Merge Sort, and Selection Sort across five input sizes ranging from 1,000 to 20,000 elements. The `n_list` was specifically set to `[1000, 2000, 5000, 10000, 20000]` to prevent `KeyboardInterrupt` errors previously encountered with Selection Sort on larger datasets.
# *   Quick Sort and Merge Sort consistently demonstrated significantly faster execution times compared to Selection Sort, particularly as the number of elements (\_n\`) increased.
#     *   For \$n = 20,000\$, Quick Sort completed in approximately 32.14 ms, and Merge Sort in 53.07 ms.
#     *   In stark contrast, Selection Sort took about 11,075.74 ms for \$n = 20,000\$.
# *   The performance gap between Quick Sort/Merge Sort and Selection Sort widened dramatically with increasing input size, visually confirmed by the generated plot where Selection Sort's time curve rose sharply while the others showed a more gradual increase.
#
# ### Insights or Next Steps
# *   The results underscore the practical impact of algorithmic complexity; for larger datasets, algorithms with \$O(n \log n)\$ complexity (Quick Sort, Merge Sort) are vastly more efficient than those with \$O(n^2)\$ complexity (Selection Sort).
# *   Future analysis could explore the performance of these algorithms with different types of input data (e.g., pre-sorted, reverse-sorted, or data with many duplicates) to understand their behavior under various real-world scenarios.
